# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy.stats as stats
import math

# %% [markdown]
# __Import data from github__

# %%
url = "https://raw.githubusercontent.com/arimitramaiti/datasets/master/articles/servicetime.csv"
dataset = pd.read_csv(url, error_bad_lines=False, header=0, index_col=None)
dataset.head(4)
# Out:
#    Customer  Time
# 0         1    42
# 1         2    35
# 2         3    34
# 3         4    39

# %% [markdown]
#  - __Python Graph-1 as per article on confidence interval__
#  - __Exact numbers may change on each run due to random sample function, and may not match with published graph__

# %%
##Create the grid
fig, axes = plt.subplots(2, 3, figsize=(12,8))
fig.subplots_adjust(top=0.7)

#Chart-0 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=0)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(30) for _ in range(1)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sns.distplot(x, hist=True, kde=False, bins=10, ax=axes[0,0]);
axes[0,0].set_title("Draw 1 sample of size 30")
axes[0,0].get_yaxis().set_visible(False)
axes[0,0].spines['top'].set_visible(False)
axes[0,0].spines['right'].set_visible(False)
axes[0,0].spines['left'].set_visible(False)
axes[0,0].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[0,0].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)

#Chart-1 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(30) for _ in range(10)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - 30) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(30))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[0,1]);
axes[0,1].set_title("Draw 10 samples of size 30")
axes[0,1].get_yaxis().set_visible(False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].spines['left'].set_visible(False)
axes[0,1].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[0,1].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[0,1].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,1].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,1].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-2 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(30) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - 30) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(30))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[0,2]);
axes[0,2].set_title("Draw 100 samples of size 30")
axes[0,2].get_yaxis().set_visible(False)
axes[0,2].spines['top'].set_visible(False)
axes[0,2].spines['right'].set_visible(False)
axes[0,2].spines['left'].set_visible(False)
axes[0,2].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[0,2].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[0,2].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,2].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,2].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)


#Chart-3 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(30) for _ in range(1000)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - 30) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(30))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[1,0]);
axes[1,0].set_title("Draw 1000 samples of size 30")
axes[1,0].get_yaxis().set_visible(False)
axes[1,0].spines['top'].set_visible(False)
axes[1,0].spines['right'].set_visible(False)
axes[1,0].spines['left'].set_visible(False)
axes[1,0].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[1,0].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,0].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,0].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,0].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-4 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(30) for _ in range(10000)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - 30) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(30))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[1,1]);
axes[1,1].set_title("Draw 10k samples of size 30")
axes[1,1].get_yaxis().set_visible(False)
axes[1,1].spines['top'].set_visible(False)
axes[1,1].spines['right'].set_visible(False)
axes[1,1].spines['left'].set_visible(False)
axes[1,1].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[1,1].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,1].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,1].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,1].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-5 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(30) for _ in range(100000)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - 30) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(30))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[1,2]);
axes[1,2].set_title("Draw 100k samples of size 30")
axes[1,2].get_yaxis().set_visible(False)
axes[1,2].spines['top'].set_visible(False)
axes[1,2].spines['right'].set_visible(False)
axes[1,2].spines['left'].set_visible(False)
axes[1,2].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[1,2].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,2].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,2].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,2].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

fig.tight_layout()
plt.show()

# %% [markdown]
#  - __Python Graph-2 as per article on confidence interval__

# %%
##Create the grid
fig, axes = plt.subplots(2, 3, figsize=(12,8))
fig.subplots_adjust(top=0.7)

size = 100
#Chart-0 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=0)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(1)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sns.distplot(x, hist=True, kde=False, bins=10, ax=axes[0,0]);
axes[0,0].set_title("Draw 1 sample of size 100")
axes[0,0].get_yaxis().set_visible(False)
axes[0,0].spines['top'].set_visible(False)
axes[0,0].spines['right'].set_visible(False)
axes[0,0].spines['left'].set_visible(False)
axes[0,0].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[0,0].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)

#Chart-1 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(10)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[0,1]);
axes[0,1].set_title("Draw 10 samples of size 100")
axes[0,1].get_yaxis().set_visible(False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].spines['left'].set_visible(False)
axes[0,1].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[0,1].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[0,1].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,1].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,1].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-2 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[0,2]);
axes[0,2].set_title("Draw 100 samples of size 100")
axes[0,2].get_yaxis().set_visible(False)
axes[0,2].spines['top'].set_visible(False)
axes[0,2].spines['right'].set_visible(False)
axes[0,2].spines['left'].set_visible(False)
axes[0,2].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[0,2].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[0,2].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,2].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[0,2].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)


#Chart-3 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(1000)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[1,0]);
axes[1,0].set_title("Draw 1000 samples of size 100")
axes[1,0].get_yaxis().set_visible(False)
axes[1,0].spines['top'].set_visible(False)
axes[1,0].spines['right'].set_visible(False)
axes[1,0].spines['left'].set_visible(False)
axes[1,0].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[1,0].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,0].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,0].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,0].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-4 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(10000)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[1,1]);
axes[1,1].set_title("Draw 10k samples of size 100")
axes[1,1].get_yaxis().set_visible(False)
axes[1,1].spines['top'].set_visible(False)
axes[1,1].spines['right'].set_visible(False)
axes[1,1].spines['left'].set_visible(False)
axes[1,1].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[1,1].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,1].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,1].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,1].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-5 plotting
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100000)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))
iright = round(x.Avg_Time.mean(),2) + (2 * sampling_stderr)
ileft = round(x.Avg_Time.mean(),2) - (2 * sampling_stderr)

sns.distplot(x, hist=True, kde=True, bins=10, kde_kws = {'color': "green"}, ax=axes[1,2]);
axes[1,2].set_title("Draw 100k samples of size 100")
axes[1,2].get_yaxis().set_visible(False)
axes[1,2].spines['top'].set_visible(False)
axes[1,2].spines['right'].set_visible(False)
axes[1,2].spines['left'].set_visible(False)
axes[1,2].set_xlabel('Sample Mean', fontsize=11, weight='bold')
axes[1,2].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,2].axvline(x=round(ileft,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,2].axvline(x=round(iright,2), color='red', linestyle='dashed', linewidth=1.5)
axes[1,2].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

fig.tight_layout()
plt.show()

# %% [markdown]
#  - __Python Graph-3 as per article on confidence interval__

# %%
fig, axes = plt.subplots(2, 3, figsize=(12,8))
fig.subplots_adjust(top=0.7)

#Chart-0 plotting
size=3
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))

sns.distplot(dataset.Time, hist=False, kde=True, bins=10, label="Population distribution", ax=axes[0,0])
sns.distplot(x, hist=False, kde=True, bins=10, kde_kws = {'color': "green"}, label="Sample distribution", ax=axes[0,0]);
axes[0,0].legend(loc="best")
axes[0,0].set_title("Sample size : 3")
axes[0,0].get_yaxis().set_visible(False)
axes[0,0].spines['top'].set_visible(False)
axes[0,0].spines['right'].set_visible(False)
axes[0,0].spines['left'].set_visible(False)
axes[0,0].set_xlabel('Time', fontsize=11, weight='bold')
axes[0,0].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[0,0].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)


#Chart-1 plotting
size=5
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))

sns.distplot(dataset.Time, hist=False, kde=True, bins=10, label="Population distribution", ax=axes[0,1])
sns.distplot(x, hist=False, kde=True, bins=10, kde_kws = {'color': "green"}, label="Sample distribution", ax=axes[0,1]);
axes[0,1].legend(loc="best")
axes[0,1].set_title("Sample size : 5")
axes[0,1].get_yaxis().set_visible(False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].spines['left'].set_visible(False)
axes[0,1].set_xlabel('Time', fontsize=11, weight='bold')
axes[0,1].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[0,1].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-2 plotting
size=25
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))

sns.distplot(dataset.Time, hist=False, kde=True, bins=10, label="Population distribution", ax=axes[0,2])
sns.distplot(x, hist=False, kde=True, bins=10, kde_kws = {'color': "green"}, label="Sample distribution", ax=axes[0,2]);
axes[0,2].legend(loc="best")
axes[0,2].set_title("Sample size : 25")
axes[0,2].get_yaxis().set_visible(False)
axes[0,2].spines['top'].set_visible(False)
axes[0,2].spines['right'].set_visible(False)
axes[0,2].spines['left'].set_visible(False)
axes[0,2].set_xlabel('Time', fontsize=11, weight='bold')
axes[0,2].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[0,2].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-3 plotting
size=30
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))

sns.distplot(dataset.Time, hist=False, kde=True, bins=10, label="Population distribution", ax=axes[1,0])
sns.distplot(x, hist=False, kde=True, bins=10, kde_kws = {'color': "green"}, label="Sample distribution", ax=axes[1,0]);
axes[1,0].legend(loc="best")
axes[1,0].set_title("Sample size : 30")
axes[1,0].get_yaxis().set_visible(False)
axes[1,0].spines['top'].set_visible(False)
axes[1,0].spines['right'].set_visible(False)
axes[1,0].spines['left'].set_visible(False)
axes[1,0].set_xlabel('Time', fontsize=11, weight='bold')
axes[1,0].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,0].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-4 plotting
size=50
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))

sns.distplot(dataset.Time, hist=False, kde=True, bins=10, label="Population distribution", ax=axes[1,1])
sns.distplot(x, hist=False, kde=True, bins=10, kde_kws = {'color': "green"}, label="Sample distribution", ax=axes[1,1]);
axes[1,1].legend(loc="best")
axes[1,1].set_title("Sample size : 50")
axes[1,1].get_yaxis().set_visible(False)
axes[1,1].spines['top'].set_visible(False)
axes[1,1].spines['right'].set_visible(False)
axes[1,1].spines['left'].set_visible(False)
axes[1,1].set_xlabel('Time', fontsize=11, weight='bold')
axes[1,1].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,1].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

#Chart-5 plotting
size=100
def sample_mean(sample_frame):
    sampling_units = list()
    rows = sample_frame
    subset = dataset.loc[ : , "Time"].sample(n=rows).mean()
    subset = round(subset, ndigits=2)
    sampling_units.append(subset)

    return sampling_units

sample_mean = [sample_mean(size) for _ in range(100)]

x = pd.DataFrame(np.concatenate(sample_mean), columns=["Avg_Time"])
sampling_std = x.Avg_Time.std()
fpc = round(np.sqrt((dataset.shape[0] - size) / (dataset.shape[0] - 1)),2)
sampling_stderr = fpc * (sampling_std/np.sqrt(size))

sns.distplot(dataset.Time, hist=False, kde=True, bins=10, label="Population distribution", ax=axes[1,2])
sns.distplot(x, hist=False, kde=True, bins=10, kde_kws = {'color': "green"}, label="Sample distribution", ax=axes[1,2]);
axes[1,2].legend(loc="best")
axes[1,2].set_title("Sample size : 100")
axes[1,2].get_yaxis().set_visible(False)
axes[1,2].spines['top'].set_visible(False)
axes[1,2].spines['right'].set_visible(False)
axes[1,2].spines['left'].set_visible(False)
axes[1,2].set_xlabel('Time', fontsize=11, weight='bold')
axes[1,2].axvline(x=round(dataset.Time.mean(),2), color='black', linestyle='dashdot', linewidth=1)
axes[1,2].axvline(x=round(x.Avg_Time.mean(),2), color='brown', linestyle='solid', linewidth=1.5)

fig.tight_layout()
plt.show()

# %% [markdown]
#  - __Python method to generate 95% cdf__

# %%
x = round(stats.norm.ppf(0.975),2) #x gives us 1.96 instead of 2.0
b = stats.norm.cdf(x)
a = stats.norm.cdf(-x)
y = round(b-a, 6)
print(y)
# Out:
# 0.950004

# %% [markdown]
#  - __Python Graph-4 as per article on confidence interval__

# %%
##Create the grid
fig, axes = plt.subplots(2, 3, figsize=(12,8))
fig.subplots_adjust(top=0.7)

##Common data
mu = 0
sigma = 1

x = np.arange(-3,3,0.001)
y = stats.norm.pdf(x, mu, sigma)
##Common data

#Chart-0 plotting
z0 = stats.t.pdf(x, df=2)
axes[0,0].plot(x, y, label="N(0,1)", linewidth=1.75, linestyle='dashdot')
axes[0,0].plot(x, z0, color="orange", label="t w/t 2 df")
axes[0,0].set_title("Compare N(0,1) with Student's-t(2)")
axes[0,0].get_yaxis().set_visible(False)
axes[0,0].spines['top'].set_visible(False)
axes[0,0].spines['right'].set_visible(False)
axes[0,0].spines['left'].set_visible(False)
axes[0,0].set_xlabel('Z-Score', fontsize=11, weight='bold')
axes[0,0].legend(loc="best")

#Chart-1 plotting
z1 = stats.t.pdf(x, df=5)
axes[0,1].plot(x, y, label="N(0,1)", linewidth=1.75, linestyle='dashdot')
axes[0,1].plot(x, z1, color="brown", label="t w/t 5 df")
axes[0,1].set_title("Compare N(0,1) with Student's-t(5)")
axes[0,1].get_yaxis().set_visible(False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].spines['left'].set_visible(False)
axes[0,1].set_xlabel('Z-Score', fontsize=11, weight='bold')
axes[0,1].legend(loc="best")

#Chart-2 plotting
z2 = stats.t.pdf(x, df=10)
axes[0,2].plot(x, y, label="N(0,1)", linewidth=1.75, linestyle='dashdot')
axes[0,2].plot(x, z2, color="green", label="t w/t 10 df")
axes[0,2].set_title("Compare N(0,1) with Student's-t(10)")
axes[0,2].get_yaxis().set_visible(False)
axes[0,2].spines['top'].set_visible(False)
axes[0,2].spines['right'].set_visible(False)
axes[0,2].spines['left'].set_visible(False)
axes[0,2].set_xlabel('Z-Score', fontsize=11, weight='bold')
axes[0,2].legend(loc="best")

#Chart-3 plotting
z3 = stats.t.pdf(x, df=30)
axes[1,0].plot(x, y, label="N(0,1)", linewidth=1.75, linestyle='dashdot')
axes[1,0].plot(x, z3, color="red", label="t w/t 30 df")
axes[1,0].set_title("Compare N(0,1) with Student's-t(30)")
axes[1,0].get_yaxis().set_visible(False)
axes[1,0].spines['top'].set_visible(False)
axes[1,0].spines['right'].set_visible(False)
axes[1,0].spines['left'].set_visible(False)
axes[1,0].set_xlabel('Z-Score', fontsize=11, weight='bold')
axes[1,0].legend(loc="best")

#Chart-4 plotting
z4 = stats.t.pdf(x, df=50)
axes[1,1].plot(x, y, label="N(0,1)", linewidth=1.75, linestyle='dashdot')
axes[1,1].plot(x, z4, color="yellow", label="t w/t 50 df")
axes[1,1].set_title("Compare N(0,1) with Student's-t(50)")
axes[1,1].get_yaxis().set_visible(False)
axes[1,1].spines['top'].set_visible(False)
axes[1,1].spines['right'].set_visible(False)
axes[1,1].spines['left'].set_visible(False)
axes[1,1].set_xlabel('Z-Score', fontsize=11, weight='bold')
axes[1,1].legend(loc="best")

#Chart-4 plotting
z5 = stats.t.pdf(x, df=100)
axes[1,2].plot(x, y, label="N(0,1)", linewidth=1.75, linestyle='dashdot')
axes[1,2].plot(x, z5, color="black", label="t w/t 100 df")
axes[1,2].set_title("Compare N(0,1) with Student's-t(100)")
axes[1,2].get_yaxis().set_visible(False)
axes[1,2].spines['top'].set_visible(False)
axes[1,2].spines['right'].set_visible(False)
axes[1,2].spines['left'].set_visible(False)
axes[1,2].set_xlabel('Z-Score', fontsize=11, weight='bold')
axes[1,2].legend(loc="best")

fig.tight_layout()
plt.show()

# %% [markdown]
#  - __Python code to solve the given proportion problem in article on confidence interval__

# %%
sample_size = 40 #known from the sample collected by the manager
sample_success = 25 #known from the sample collected by the manager
proportion = sample_success/sample_size #sample proportion who rated more 6 or more
point_estmate = proportion #similar to proportion of the sample
standard_error = np.sqrt((proportion * (1-proportion))/sample_size) #formula is slightly different relative to population mean estimation

upper_limit = round(point_estmate + (stats.norm.ppf(0.975) * standard_error),3) #upper side of the interval
lower_limit = round(point_estmate - (stats.norm.ppf(0.975) * standard_error),3) #lower side of the interval

print("We are 95% confident that proportion of customers who rated the sandwich 6 & above lies between {}. and {}.".format(lower_limit, upper_limit))
# Out:
# We are 95% confident that proportion of customers who rated the sandwich 6 & above lies between 0.475. and 0.775.

# %% [markdown]
#  - __Thank You__
